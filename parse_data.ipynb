# %%
# In this notebook, our goal is to parse data to use later in models

import os
import pandas as pd
from bs4 import BeautifulSoup
from io import StringIO
# %pip install pandas

# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
SCORE_DIR = "data/scores"

# %%
box_scores = os.listdir(SCORE_DIR)

# %%
len(box_scores)
# Out:
# 454

# %%
box_scores = [os.path.join(SCORE_DIR, f) for f in box_scores if f.endswith(".html")]

# %%
box_scores
# Out:
# ['data/scores/202001160NOP.html',
#  'data/scores/202001170DAL.html',
#  'data/scores/202106100MIL.html',
#  'data/scores/202110200POR.html',
#  'data/scores/202001060SAC.html',
#  'data/scores/202001040BRK.html',
#  'data/scores/202106100UTA.html',
#  'data/scores/202009130DEN.html',
#  'data/scores/202001040CHI.html',
#  'data/scores/202110260OKC.html',
#  'data/scores/202003020CLE.html',
#  'data/scores/202110270OKC.html',
#  'data/scores/202110280PHI.html',
#  'data/scores/202001220DET.html',
#  'data/scores/202001220MIA.html',
#  'data/scores/202001240NYK.html',
#  'data/scores/202001280DAL.html',
#  'data/scores/202110270BRK.html',
#  'data/scores/202001100PHO.html',
#  'data/scores/202001220ATL.html',
#  'data/scores/202003060NOP.html',
#  'data/scores/202003060DAL.html',
#  'data/scores/202110270TOR.html',
#  'data/scores/202009060LAL.html',
#  'data/scores/202110240SAC.html',
#  'data/scores/202106120LAC.html',
#  'data/scores/202001200CHO.html',
#  'data/scores/202110270BOS.html',
#  'data/scores/202001030WAS.html',
#  'data/scores/202001010MIL.html',
#  'data/scores/202106260LAC.html',
#  'data/scores/202110220PHI.html',
#  'data/scores/202001280MIA.html',
#  'data/scores/202003110PHI.html',
#  'data/scores/202003080CLE.html',
#  'data/scores/202110260SAS.html',
#  'data/scores/202003070DET.html',
#  'data/scores/202106150BRK.html',
#  'data/scores/202001100NYK.html',
#  'data/scores/202001040GSW.html',
#  'data/scores/202106180LAC.html',
#  'data/scores/202009150LAC.html',
#  'data/scores/202106010PHO.html',
#  'data/scores/202001020LAC.html',
#  'data/scores/202106250MIL.html',
#  'data/scores/202001220ORL.html',
#  'data/scores/202003050CHO.html',
#  'data/scores/202001220NOP.html',
#  'data/scores/202001080CHO.html',
#  'data/scores/202009050BOS.html',
#  'data/scores/202106110ATL.html',
#  'data/scores/202110240LAL.html',
#  'data/scores/202001120BRK.html',
#  'data/scores/202106220PHO.html',
#  'data/scores/202003030OKC.html',
#  'data/scores/202001100SAC.html',
#  'data/scores/202003040POR.html',
#  'data/scores/202001130BOS.html',
#  'data/scores/202110290MIA.html',
#  'data/scores/202009230MIA.html',
#  'data/scores/202001080IND.html',
#  'data/scores/202110300MIN.html',
#  'data/scores/202001120MEM.html',
#  'data/scores/202001120DEN.html',
#  'data/scores/202001120TOR.html',
#  'data/scores/202003010SAC.html',
#  'data/scores/202001200WAS.html',
#  'data/scores/202001180GSW.html',
#  'data/scores/202110220ORL.html',
#  'data/scores/202003030BOS.html',
#  'data/scores/202106060PHI.html',
#  'data/scores/202110300MEM.html',
#  'data/scores/202003030DEN.html',
#  'data/scores/202001130MIN.html',
#  'data/scores/202003110DAL.html',
#  'data/scores/202001070LAL.html',
#  'data/scores/202110310BRK.html',
#  'data/scores/202001190SAS.html',
#  'data/scores/202110300CHI.html',
#  'data/scores/202001040CLE.html',
#  'data/scores/202001050CLE.html',
#  'data/scores/202001070PHO.html',
#  'data/scores/202003020CHI.html',
#  'data/scores/202001270OKC.html',
#  'data/scores/202001190DEN.html',
#  'data/scores/202003080MIN.html',
#  'data/scores/202001180BOS.html',
#  'data/scores/202001020IND.html',
#  'data/scores/202001280PHI.html',
#  'data/scores/202003110MIA.html',
#  'data/scores/202003080HOU.html',
#  'data/scores/202110300GSW.html',
#  'data/scores/202110240NYK.html',
#  'data/scores/202001270MIN.html',
#  'data/scores/202001180CHI.html',
#  'data/scores/202106280PHO.html',
#  'data/scores/202003020SAS.html',
#  'data/scores/202001180BRK.html',
#  'data/scores/202106300LAC.html',
#  'data/scores/202001160MIL.html',
#  'data/scores/202001200POR.html',
#  'data/scores/202001260MEM.html',
#  'data/scores/202001260DEN.html',
#  'data/scores/202001180OKC.html',
#  'data/scores/202003080BRK.html',
#  'data/scores/202001140LAC.html',
#  'data/scores/202001170PHI.html',
#  'data/scores/202110200CHO.html',
#  'data/scores/202110280DAL.html',
#  'data/scores/202001270CHI.html',
#  'data/scores/202110290NOP.html',
#  'data/scores/202001180MIN.html',
#  'data/scores/202003090DEN.html',
#  'data/scores/202003080BOS.html',
#  'data/scores/202009030LAC.html',
#  'data/scores/202003110ATL.html',
#  'data/scores/202001180HOU.html',
#  'data/scores/202001280MIL.html',
#  'data/scores/202003100LAL.html',
#  'data/scores/202110220LAL.html',
#  'data/scores/202001140BRK.html',
#  'data/scores/202001150CHI.html',
#  'data/scores/202009030BOS.html',
#  'data/scores/202003080LAC.html',
#  'data/scores/202003040MIN.html',
#  'data/scores/202001150DEN.html',
#  'data/scores/202001060NOP.html',
#  'data/scores/202001140MEM.html',
#  'data/scores/202001060DAL.html',
#  'data/scores/202003050HOU.html',
#  'data/scores/202001150BOS.html',
#  'data/scores/202001060ORL.html',
#  'data/scores/202001250PHI.html',
#  'data/scores/202001150MIN.html',
#  'data/scores/202106290ATL.html',
#  'data/scores/202001150HOU.html',
#  'data/scores/202001130POR.html',
#  'data/scores/202106020LAC.html',
#  'data/scores/202001010LAL.html',
#  'data/scores/202001250UTA.html',
#  'data/scores/202003040BRK.html',
#  'data/scores/202001020CLE.html',
#  'data/scores/202001150OKC.html',
#  'data/scores/202009020HOU.html',
#  'data/scores/202003080WAS.html',
#  'data/scores/202110250MIA.html',
#  'data/scores/202001060ATL.html',
#  'data/scores/202003050GSW.html',
#  'data/scores/202106050BRK.html',
#  'data/scores/202001100UTA.html',
#  'data/scores/202001120WAS.html',
#  'data/scores/202001260POR.html',
#  'data/scores/202001200HOU.html',
#  'data/scores/202009090BOS.html',
#  'data/scores/202001200MIN.html',
#  'data/scores/202009090DEN.html',
#  'data/scores/202110290LAL.html',
#  'data/scores/202009080HOU.html',
#  'data/scores/202106030POR.html',
#  'data/scores/202110300WAS.html',
#  'data/scores/202001200BOS.html',
#  'data/scores/202001200MEM.html',
#  'data/scores/202009050LAC.html',
#  'data/scores/202110250ATL.html',
#  'data/scores/202001140GSW.html',
#  'data/scores/202001010NYK.html',
#  'data/scores/202001200BRK.html',
#  'data/scores/202106170MIL.html',
#  'data/scores/202110270POR.html',
#  'data/scores/202001030BOS.html',
#  'data/scores/202110200MIN.html',
#  'data/scores/202001110DAL.html',
#  'data/scores/202001100DAL.html',
#  'data/scores/202106190BRK.html',
#  'data/scores/202001240DET.html',
#  'data/scores/202001250DET.html',
#  'data/scores/202001240MIA.html',
#  'data/scores/202009150BOS.html',
#  'data/scores/202001220NYK.html',
#  'data/scores/202003060LAL.html',
#  'data/scores/202106160UTA.html',
#  'data/scores/202001020CHI.html',
#  'data/scores/202003060PHO.html',
#  'data/scores/202003040CLE.html',
#  'data/scores/202106140LAC.html',
#  'data/scores/202110220SAC.html',
#  'data/scores/202001080GSW.html',
#  'data/scores/202001030HOU.html',
#  'data/scores/202106160PHI.html',
#  'data/scores/202003010NOP.html',
#  'data/scores/202001020MIN.html',
#  'data/scores/202110200MEM.html',
#  'data/scores/202110200TOR.html',
#  'data/scores/202106130DEN.html',
#  'data/scores/202110200SAS.html',
#  'data/scores/202110270LAC.html',
#  'data/scores/202001040WAS.html',
#  'data/scores/202001200CLE.html',
#  'data/scores/202001220PHO.html',
#  'data/scores/202001130IND.html',
#  'data/scores/202001080BOS.html',
#  'data/scores/202003060NYK.html',
#  'data/scores/202110210GSW.html',
#  'data/scores/202001090MIN.html',
#  'data/scores/202106070PHO.html',
#  'data/scores/202110300IND.html',
#  'data/scores/202001110DET.html',
#  'data/scores/202001160NYK.html',
#  'data/scores/202001090OKC.html',
#  'data/scores/202001240NOP.html',
#  'data/scores/202001020SAS.html',
#  'data/scores/202001040LAC.html',
#  'data/scores/202106230MIL.html',
#  'data/scores/202001050LAC.html',
#  'data/scores/202009060MIA.html',
#  'data/scores/202110310CHO.html',
#  'data/scores/202001060PHI.html',
#  'data/scores/202001240ORL.html',
#  'data/scores/202003030CHO.html',
#  'data/scores/202001240OKC.html',
#  'data/scores/202001080NOP.html',
#  'data/scores/202106010BRK.html',
#  'data/scores/202001080DAL.html',
#  'data/scores/202110260NYK.html',
#  'data/scores/202009020MIL.html',
#  'data/scores/202003010GSW.html',
#  'data/scores/202110210MIA.html',
#  'data/scores/202001080ORL.html',
#  'data/scores/202110200DET.html',
#  'data/scores/202009260LAL.html',
#  'data/scores/202001250MIN.html',
#  'data/scores/202001240MIN.html',
#  'data/scores/202106010DEN.html',
#  'data/scores/202001140MIL.html',
#  'data/scores/202001230POR.html',
#  'data/scores/202106180ATL.html',
#  'data/scores/202001150PHI.html',
#  'data/scores/202003060WAS.html',
#  'data/scores/202003040MIL.html',
#  'data/scores/202001160LAC.html',
#  'data/scores/202001240CHI.html',
#  'data/scores/202009180LAL.html',
#  'data/scores/202106270ATL.html',
#  'data/scores/202003080SAC.html',
#  'data/scores/202110210ATL.html',
#  'data/scores/202110230IND.html',
#  'data/scores/202001020MIA.html',
#  'data/scores/202003100IND.html',
#  'data/scores/202001240GSW.html',
#  'data/scores/202110270PHO.html',
#  'data/scores/202009070DEN.html',
#  'data/scores/202106200PHO.html',
#  'data/scores/202001100CHI.html',
#  'data/scores/202001100BRK.html',
#  'data/scores/202009070TOR.html',
#  'data/scores/202001110BOS.html',
#  'data/scores/202001030ORL.html',
#  'data/scores/202001130SAC.html',
#  'data/scores/202009080MIL.html',
#  'data/scores/202001080ATL.html',
#  'data/scores/202003070POR.html',
#  'data/scores/202001020DAL.html',
#  'data/scores/202001240SAS.html',
#  'data/scores/202001100MEM.html',
#  'data/scores/202001110DEN.html',
#  'data/scores/202003010MIN.html',
#  'data/scores/202001090DET.html',
#  'data/scores/202003030SAC.html',
#  'data/scores/202001110HOU.html',
#  'data/scores/202001200MIL.html',
#  'data/scores/202106060LAC.html',
#  'data/scores/202009120LAL.html',
#  'data/scores/202110190LAL.html',
#  'data/scores/202110200NOP.html',
#  'data/scores/202003010DEN.html',
#  'data/scores/202001070CLE.html',
#  'data/scores/202001050PHO.html',
#  'data/scores/202001110OKC.html',
#  'data/scores/202001200UTA.html',
#  'data/scores/202001050LAL.html',
#  'data/scores/202110230LAC.html',
#  'data/scores/202106240LAC.html',
#  'data/scores/202001010WAS.html',
#  'data/scores/202009300LAL.html',
#  'data/scores/202106040DAL.html',
#  'data/scores/202003080PHO.html',
#  'data/scores/202003020NYK.html',
#  'data/scores/202110290POR.html',
#  'data/scores/202001140ATL.html',
#  'data/scores/202003040MIA.html',
#  'data/scores/202001170IND.html',
#  'data/scores/202003040DET.html',
#  'data/scores/202001250CLE.html',
#  'data/scores/202001120NYK.html',
#  'data/scores/202001150MIA.html',
#  'data/scores/202009250BOS.html',
#  'data/scores/202001280CHO.html',
#  'data/scores/202009240DEN.html',
#  'data/scores/202106030LAL.html',
#  'data/scores/202110200UTA.html',
#  'data/scores/202003070CHO.html',
#  'data/scores/202110220WAS.html',
#  'data/scores/202003100WAS.html',
#  'data/scores/202001060SAS.html',
#  'data/scores/202001210DAL.html',
#  'data/scores/202001080UTA.html',
#  'data/scores/202001070TOR.html',
#  'data/scores/202001070MEM.html',
#  'data/scores/202110250MIN.html',
#  'data/scores/202003100POR.html',
#  'data/scores/202106130MIL.html',
#  'data/scores/202003080NYK.html',
#  'data/scores/202110240HOU.html',
#  'data/scores/202110230POR.html',
#  'data/scores/202001040SAC.html',
#  'data/scores/202003030PHO.html',
#  'data/scores/202110300PHO.html',
#  'data/scores/202110240OKC.html',
#  'data/scores/202009110TOR.html',
#  'data/scores/202001070BRK.html',
#  'data/scores/202110310LAL.html',
#  'data/scores/202003030LAL.html',
#  'data/scores/202001260NYK.html',
#  'data/scores/202001200MIA.html',
#  'data/scores/202001120PHO.html',
#  'data/scores/202110250BRK.html',
#  'data/scores/202001130LAL.html',
#  'data/scores/202110240BRK.html',
#  'data/scores/202001200ATL.html',
#  'data/scores/202110280WAS.html',
#  'data/scores/202009100HOU.html',
#  'data/scores/202106020NYK.html',
#  'data/scores/202001090PHI.html',
#  'data/scores/202003040DAL.html',
#  'data/scores/202009040LAL.html',
#  'data/scores/202110250TOR.html',
#  'data/scores/202110250DEN.html',
#  'data/scores/202106090PHO.html',
#  'data/scores/202001180NYK.html',
#  'data/scores/202110230SAS.html',
#  'data/scores/202003100SAS.html',
#  'data/scores/202106110DEN.html',
#  'data/scores/202106200PHI.html',
#  'data/scores/202110250LAC.html',
#  'data/scores/202001060WAS.html',
#  'data/scores/202001040MIL.html',
#  'data/scores/202001230CLE.html',
#  'data/scores/202001180NOP.html',
#  'data/scores/202001200PHO.html',
#  'data/scores/202110280HOU.html',
#  'data/scores/202003040NYK.html',
#  'data/scores/202003100GSW.html',
#  'data/scores/202110190MIL.html',
#  'data/scores/202110300DET.html',
#  'data/scores/202003020MIA.html',
#  'data/scores/202110290DEN.html',
#  'data/scores/202009220DEN.html',
#  'data/scores/202003080DAL.html',
#  'data/scores/202110260UTA.html',
#  'data/scores/202110290TOR.html',
#  'data/scores/202003020ATL.html',
#  'data/scores/202009110LAC.html',
#  'data/scores/202001130DET.html',
#  'data/scores/202110290BRK.html',
#  'data/scores/202001260NOP.html',
#  'data/scores/202110280CHI.html',
#  'data/scores/202009040MIA.html',
#  'data/scores/202003010CHO.html',
#  'data/scores/202001260ORL.html',
#  'data/scores/202110270MIL.html',
#  'data/scores/202110220HOU.html',
#  'data/scores/202001020SAC.html',
#  'data/scores/202110280GSW.html',
#  'data/scores/202003100HOU.html',
#  'data/scores/202001180ATL.html',
#  'data/scores/202001280CLE.html',
#  'data/scores/202110230MIN.html',
#  'data/scores/202001270DET.html',
#  'data/scores/202009170BOS.html',
#  'data/scores/202001270MIA.html',
#  'data/scores/202003070CLE.html',
#  'data/scores/202001260ATL.html',
#  'data/scores/202003100CHI.html',
#  'data/scores/202110230CHI.html',
#  'data/scores/202110220CHI.html',
#  'data/scores/202001150LAL.html',
#  'data/scores/202110220BOS.html',
#  'data/scores/202001240CHO.html',
#  'data/scores/202003020ORL.html',
#  'data/scores/202003090ATL.html',
#  'data/scores/202110230TOR.html',
#  'data/scores/202110310DAL.html',
#  'data/scores/202003100MEM.html',
#  'data/scores/202003030NOP.html',
#  'data/scores/202110220DEN.html',
#  'data/scores/202110300NOP.html',
#  'data/scores/202001040ATL.html',
#  'data/scores/202110200NYK.html',
#  'data/scores/202003070GSW.html',
#  'data/scores/202106070BRK.html',
#  'data/scores/202001060CHO.html',
#  'data/scores/202110300PHI.html',
#  'data/scores/202003010LAC.html',
#  'data/scores/202001100WAS.html',
#  'data/scores/202001220HOU.html',
#  'data/scores/202106080UTA.html',
#  'data/scores/202009200LAL.html',
#  'data/scores/202110250CHO.html',
#  'data/scores/202001220BOS.html',
#  'data/scores/202001100LAC.html',
#  'data/scores/202110310MIL.html',
#  'data/scores/202110300MIL.html',
#  'data/scores/202001220TOR.html',
#  'data/scores/202001170SAS.html',
#  'data/scores/202001160GSW.html',
#  'data/scores/202110250IND.html',
#  'data/scores/202001050MIA.html',
#  'data/scores/202106080PHI.html',
#  'data/scores/202001220CHI.html',
#  'data/scores/202001230BRK.html',
#  'data/scores/202110200PHO.html',
#  'data/scores/202110220CLE.html',
#  'data/scores/202110230CLE.html',
#  'data/scores/202009010DEN.html',
#  'data/scores/202106020UTA.html',
#  'data/scores/202009010TOR.html',
#  'data/scores/202001220GSW.html',
#  'data/scores/202106140ATL.html',
#  'data/scores/202001180UTA.html',
#  'data/scores/202001040DAL.html',
#  'data/scores/202001170TOR.html',
#  'data/scores/202001170MEM.html',
#  'data/scores/202003060MIN.html',
#  'data/scores/202009270MIA.html',
#  'data/scores/202001040ORL.html',
#  'data/scores/202001150SAC.html',
#  'data/scores/202110260DAL.html',
#  'data/scores/202003090UTA.html',
#  'data/scores/202110270NOP.html',
#  'data/scores/202003070MEM.html',
#  'data/scores/202003060BOS.html',
#  'data/scores/202110270ORL.html',
#  'data/scores/202106020PHI.html',
#  'data/scores/202003050SAC.html',
#  'data/scores/202001110POR.html',
#  'data/scores/202001280MEM.html',
#  'data/scores/202001030PHO.html',
#  'data/scores/202001170OKC.html',
#  'data/scores/202003060CHI.html',
#  'data/scores/202001270UTA.html',
#  'data/scores/202001280TOR.html',
#  'data/scores/202001030LAL.html',
#  'data/scores/202003060BRK.html',
#  'data/scores/202009190MIA.html']

# %%
# Since we downloaded the html in the previous notebook, its time to parse it
# Here we clean up the html by removing over_head and thead

def parse_html(box_score):
    with open(box_score) as f:
        html = f.read()
        
    soup = BeautifulSoup(html)
    [s.decompose() for s in soup.select("tr.over_header")]
    [s.decompose() for s in soup.select("tr.thead")]
    return soup

# %%
# This function grabs the scores and assigns them accordingly

def read_line_score(soup):
    line_score = pd.read_html(StringIO(str(soup)), attrs={"id": "line_score"})[0]
    cols = list(line_score.columns)
    cols[0] = "team"
    cols[-1] = "total"
    line_score.columns = cols

    line_score = line_score[["team", "total"]]
    return line_score

# %%
def read_stats(soup, team, stat):
    df = pd.read_html(StringIO(str(soup)), attrs={"id": f"box-{team}-game-{stat}"}, index_col=0)[0]
    df = df.apply(pd.to_numeric, errors="coerce")
    return df

# %%
def read_season_info(soup):
    nav = soup.select("#bottom_nav_container")[0]
    hrefs = [a["href"] for a in nav.find_all("a")]
    season = os.path.basename(hrefs[1]).split("_")[0]
    return season

# %%
base_cols = None
games = []

for box_score in box_scores:
    soup = parse_html(box_score)
    line_score = read_line_score(soup)
    teams = list(line_score["team"])
    
    # Getting stats ready for machine learning application
    # Data processing and data clean up
    # Summaries contains data from both teams
    summaries = []
    for team in teams:
        # Individual stats for each player advanced and basic metrics
        basic = read_stats(soup, team, "basic")
        advanced = read_stats(soup, team, "advanced")
    
        # Puts all values into a single column, giving team totals
        totals = pd.concat([basic.iloc[-1,:], advanced.iloc[-1,:]])
        totals.index = totals.index.str.lower()
    
        # Maximum value for each player, take the best player in each category
        maxes = pd.concat([basic.iloc[:-1,:].max(), advanced.iloc[:-1,:].max()])
        maxes.index = maxes.index.str.lower() + "_max"
    
        summary = pd.concat([totals, maxes])
    
        # Some table discrepencies so we have to make sure the data is consistent
        # Remove duplicates while we are at it
        if base_cols is None:
            base_cols = list(summary.index.drop_duplicates(keep="first"))
            base_cols = [b for b in base_cols if "bpm" not in b]
    
        summary = summary[base_cols]
        summaries.append(summary)
    summary = pd.concat(summaries, axis=1).T
    game = pd.concat([summary, line_score], axis=1)
    
    game ["home"] = [0,1]
    game_opp = game.iloc[::-1].reset_index()
    game_opp.columns += "_opp"
    
    # Concatenating opponent and home for one game
    full_game = pd.concat([game, game_opp], axis=1)
    
    full_game["season"] = read_season_info(soup)
    full_game["date"] = os.path.basename(box_score)[:8]
    
    full_game["date"] = pd.to_datetime(full_game["date"], format="%Y%m%d")
    full_game["won"] = full_game["total"] > full_game["total_opp"]
    games.append(full_game)

    if len(games) % 100 == 0:
        print(f"{len(games)} / {len(box_scores)}")
# Out:
# 100 / 454
# 200 / 454
# 300 / 454
# 400 / 454

# %%
full_game
# Out:
#       mp     mp    fg    fga    fg%    3p   3pa    3p%    ft   fta  ...  \
# 0  265.0  265.0  46.0  100.0  0.460  15.0  39.0  0.385  25.0  32.0  ...
# 1  265.0  265.0  51.0   93.0  0.548  11.0  26.0  0.423  25.0  35.0  ...
#
#    tov%_max_opp  usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  \
# 0          20.7          39.9         160.0         125.0       NOP
# 1          25.0          39.5         197.0         132.0       UTA
#
#    total_opp  home_opp  season       date    won
# 0        138         1    2020 2020-01-16  False
# 1        132         0    2020 2020-01-16   True
#
# [2 rows x 154 columns]

# %%
games_df = pd.concat(games, ignore_index=True)

# %%
games_df
# Out:
#         mp     mp    fg    fga    fg%    3p   3pa    3p%    ft   fta  ...  \
# 0    265.0  265.0  46.0  100.0  0.460  15.0  39.0  0.385  25.0  32.0  ...
# 1    265.0  265.0  51.0   93.0  0.548  11.0  26.0  0.423  25.0  35.0  ...
# 2    240.0  240.0  44.0   85.0  0.518   9.0  30.0  0.300  15.0  22.0  ...
# 3    240.0  240.0  39.0   89.0  0.438  20.0  47.0  0.426  22.0  28.0  ...
# 4    240.0  240.0  34.0   94.0  0.362   8.0  32.0  0.250   7.0   8.0  ...
# ..     ...    ...   ...    ...    ...   ...   ...    ...   ...   ...  ...
# 903  240.0  240.0  43.0   86.0  0.500  14.0  29.0  0.483  23.0  28.0  ...
# 904  240.0  240.0  43.0   92.0  0.467  10.0  34.0  0.294  24.0  27.0  ...
# 905  240.0  240.0  51.0   96.0  0.531  15.0  36.0  0.417  22.0  31.0  ...
# 906  240.0  240.0  41.0   85.0  0.482   9.0  26.0  0.346  26.0  30.0  ...
# 907  240.0  240.0  33.0   85.0  0.388  12.0  44.0  0.273  28.0  34.0  ...
#
#      tov%_max_opp  usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  \
# 0            20.7          39.9         160.0         125.0       NOP
# 1            25.0          39.5         197.0         132.0       UTA
# 2            29.1          36.5         153.0         120.0       DAL
# 3            20.0          36.3         157.0         131.0       POR
# 4            12.5          41.2         136.0          94.0       MIL
# ..            ...           ...           ...           ...       ...
# 903          20.0          35.3         149.0         125.0       NOP
# 904          17.2          27.6         159.0         115.0       BRK
# 905          13.9          29.1         200.0         136.0       SAS
# 906          27.7          27.1         150.0         126.0       MIA
# 907          51.5          36.2         141.0         114.0       BOS
#
#      total_opp  home_opp  season       date    won
# 0          138         1    2020 2020-01-16  False
# 1          132         0    2020 2020-01-16   True
# 2          120         1    2020 2020-01-17  False
# 3          112         0    2020 2020-01-17   True
# 4           86         1    2021 2021-06-10  False
# ..         ...       ...     ...        ...    ...
# 903        113         0    2020 2020-01-03   True
# 904        139         1    2020 2020-03-06  False
# 905        120         0    2020 2020-03-06   True
# 906        106         1    2020 2020-09-19   True
# 907        117         0    2020 2020-09-19  False
#
# [908 rows x 154 columns]

# %%
[g.shape[1] for g in games if g.shape[1] != 154]
# Out:
# []

# %%
games_df.to_csv("nba_games.csv")
